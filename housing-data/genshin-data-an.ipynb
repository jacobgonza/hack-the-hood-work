# %%
import pandas as pd

# pd.options.display.max_columns = None
# pd.options.display.max_rows = None

# %%
genshin_data = pd.read_csv("CharAtbMax.csv")

genshin_data
# Out:
#            Personagem  Level         Arma     HP  ATK  DEF  SPAtrib  \
# 0               Amber     90         Arco   9461  223  601    0.240
# 1             Barbara     90  Catalisador   9787  159  669    0.240
# 2              Beidou     90      Espadão  13050  225  648    0.240
# 3             Bennett     90       Espada  12397  191  771    0.267
# 4            Chongyun     90      Espadão  10984  223  648    0.240
# 5               Diluc     90      Espadão  12981  335  784    0.192
# 6              Fischl     90         Arco   9189  244  594    0.240
# 7                Jean     90       Espada  14695  239  769    0.222
# 8               Kaeya     90       Espada  11636  223  792    0.267
# 9              Keqing     90       Espada  13103  323  799    0.384
# 10               Klee     90  Catalisador  10287  311  615    0.288
# 11               Lisa     90  Catalisador   9570  232  573   96.000
# 12               Mona     90  Catalisador  10409  287  653    0.320
# ...

# %% [markdown]
# # genshin data fetute key

# %%
# we want to outline the question we will be addressing through our data

# %% [markdown]
# ## characerters that have a lower HP stat will have a higher stat in what?
# ## character that have a higher crit damage stat will have a lower stat in what?
# ## dose a character using a clamor give them better stats?
# ## Question
# ## Question
# ## Question
# ## Question
# ## Question
# ## Question
# ## Question
