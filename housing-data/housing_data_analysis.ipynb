# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# pd.options.display.max_columns = None
# pd.options.display.max_rows = None

# %%
hostel_data = pd.read_csv("Hostel.csv")

hostel_data
# Out:
#      Unnamed: 0                   hostel.name          City  price.from  \
# 0             1  "Bike & Bed" CharinCo Hostel         Osaka        3300
# 1             2                  & And Hostel  Fukuoka-City        2600
# 2             3         &And Hostel Akihabara         Tokyo        3600
# 3             4              &And Hostel Ueno         Tokyo        2600
# 4             5    &And Hostel-Asakusa North-         Tokyo        1500
# ..          ...                           ...           ...         ...
# 337         338       YADOYA Guesthouse Green         Tokyo        2300
# 338         339      YADOYA Guesthouse Orange         Tokyo        2000
# 339         340             YAWP! backpackers         Tokyo        2500
# 340         341               You En Me House         Kyoto        2800
# 341         342               Zabutton Hostel         Tokyo        2900
#
#                     Distance  summary.score rating.band  atmosphere  \
# ...

# %% [markdown]
# ## 1. Which of the hostel's attributes have the most effect on the summary score? /
#
# The summary score is most affected by the facilities attribute based on the heat map. I agree and understand why that is because if you are staying at a hostel for an extended amount of time, you want the facilities to be clean and working properly also it will just be a big inconvenience.
#
# ## 2. Does cleanliness have a direct effect with the price? /
#
# I believed that cleanliness would have had a big effect on price, but it turned out that it still had an effect on it but less than I thought. the reason is because of the heat map not being a brighter square when comparing price and cleanness.
#
# ## 3. Are hostels with a higher facilities score more expensive? /
#
# I didn't think that facilities would be such a big attribute but thinking now I do understand why it has the most effect on price based on the heat map.
#
# ## 4. if the rating band is not superb or fabulous then is the summary score 8 or below? /
#
# Yes, from the data set if the rating band is not superb or fabulous the summary score is not even 8 but just barely 7.9 and lower.
#
# ## 5. Which cities has the most amount of clean hostels? /
#
# I believe that the city with the cleanest hostels is going to be Tokyo because it's the most popular/ tourist city. But based on the data set, Tokyo was actually second to Kyoto by 2. Tokyo has 17 clean hostels and Kyoto has 19 clean hostels.
#
# ## 6. Which city has the cheapest hostels within a 6 kilometer distance from the city center? /
#
# The cheapest hostel with a 6 kilometer distance from a city center is The Pax Hostel/Records/More with a cheap price of 2300 yen which is around 230 usd.
#
# ## 7. Which hostels in Fukuoka have the best atmosphere? /
#
# Within the data I found multiple hostels with a 10/10 atmosphere. Here are all the ones I found: Common de Hostel & Bar, Guest House Kaine, Norishico Auto Guesthouse, and Tabicolle Backpackers.
#
# ## 8. How many hostels in Tokyo give me a 10/10 value for my money? /
#
# The amount of hostels in Tokyo that have a 10/10 value for my money rating is 13. Surprisingly from the data set Tokyo has some really good hostels with a high rating of value for money.
#
# ## 9. How many hostels in Tokyo have a security rating of 10? /
#
# There are 13 hostels in Tokyo with a security score of 10. Tokyo has some really secure hostels to keep your personal belongings safe.
#
# ## 10. Which city has the worst atmosphere in their hostels?
#
# There were 4 hostels with an atmosphere rating of 2 and one was from Tokyo, another was from Kyoto, but two were from Osaka. So from the data set Osaka is home to two of the worst atmospheres in a hostel.

# %%
hostle_data = pd.read_csv("Hostel.csv")

lower_rated_hostle = []

for index, row in hostel_data.iterrows():
    if row["rating.band"] == "Superb" or row["rating.band"] == "Fabulous" :
        continue
        
    lower_rated_hostle.append(row)
lower_rated_hostle = pd.DataFrame(lower_rated_hostle)
lower_rated_hostle
# Out:
#      Unnamed: 0                           hostel.name          City  \
# 3             4                      &And Hostel Ueno         Tokyo
# 5             6                1night1980hostel Tokyo         Tokyo
# 8             9              3Q House - Asakusa Smile         Tokyo
# 9            10                      Ace Inn Shinjuku         Tokyo
# 18           19              AS House (Asakusa Smile)         Tokyo
# 34           35                  bnb+ Ninja Dojo Ueno         Tokyo
# 35           36                   bnb+Shinjuku Castle         Tokyo
# 43           44                        Calendar Hotel         Kyoto
# 44           45  Capsule Hotel Anshin Oyado Akihabara         Tokyo
# 45           46  Capsule Hotel Anshin Oyado Shinbashi         Tokyo
# 50           51                          Casa Macondo         Osaka
# 67           68                          Ezstay Osaka         Osaka
# 69           70          Family & bAKpAK Tokyo Hostel         Tokyo
# ...

# %%
fukuoka_hostel = []

for index, row in hostel_data.iterrows():
    if row["City"] == "Fukuoka-City":
        fukuoka_hostel.append(row)
        
fukuoka_hostel = pd.DataFrame(fukuoka_hostel)

fukuoka_hostel
# Out:
#      Unnamed: 0                    hostel.name          City  price.from  \
# 1             2                   & And Hostel  Fukuoka-City        2600
# 30           31                      Bed Stock  Fukuoka-City        2500
# 40           41     Book And Bed Tokyo Fukuoka  Fukuoka-City        4300
# 59           60         Common de Hostel & Bar  Fukuoka-City        2500
# 72           73     Fukuoka Backpackers Hostel  Fukuoka-City        2300
# 73           74            Fukuoka Hana Hostel  Fukuoka-City        2500
# 90           91           Guest House Hokorobi  Fukuoka-City        2400
# 91           92              Guest House Kaine  Fukuoka-City        2500
# 117         118  Harborside Guest House MINATO  Fukuoka-City        2500
# 119         120                  HATAGO tenjin  Fukuoka-City        2300
# 157         158             Hostel Stand By Me  Fukuoka-City        4000
# 159         160                    Hostel TOKI  Fukuoka-City        2800
# ...

# %%
correlation = hostel_data.corr()


fig, ax = plt.subplots(figsize=(20,10))
sns.heatmap(correlation, xticklabels=correlation.columns,yticklabels=correlation.columns, ax = ax)
# Out:
# <AxesSubplot:>

# %%
clean_hostel = []

for index, row in hostel_data.iterrows():
    if row["cleanliness"] == 10:
        clean_hostel.append(row)
        
clean_hostel = pd.DataFrame(clean_hostel)

clean_hostel
# Out:
#      Unnamed: 0                                   hostel.name          City  \
# 12           13                          Akihabara Hotel 3000         Tokyo
# 29           30              Beagle Tokyo Hostel & Apartments         Tokyo
# 38           39                    Book and Bed Tokyo - Kyoto         Kyoto
# 40           41                    Book And Bed Tokyo Fukuoka  Fukuoka-City
# 46           47        Capsule Hotel Asahi Plaza Shinsaibashi         Osaka
# 47           48                        Capsule Inn Kinshichou         Tokyo
# 48           49                   Capsule Resort Kyoto Square         Kyoto
# 54           55                                   Chaganjutei         Kyoto
# 57           58                                       Colours         Kyoto
# 59           60                        Common de Hostel & Bar  Fukuoka-City
# 70           71                                   Friends Kyo         Kyoto
# ...

# %%
close_hostel = []

for index, row in hostel_data.iterrows():
    if row["Distance"] == "6km from city centre":
        close_hostel.append(row)
        
close_hostel = pd.DataFrame(close_hostel)

close_hostel
# Out:
#      Unnamed: 0                          hostel.name          City  \
# 90           91                 Guest House Hokorobi  Fukuoka-City
# 231         232  Music Uni Street Backpackers Hostel         Osaka
# 312         313          The Pax Hostel/Records/More         Osaka
#
#      price.from              Distance  summary.score rating.band  atmosphere  \
# 90         2400  6km from city centre            8.4    Fabulous         7.7
# 231        3000  6km from city centre            8.9    Fabulous         9.0
# 312        2300  6km from city centre            9.5      Superb         9.5
#
#      cleanliness  facilities  location.y  security  staff  valueformoney  \
# 90           8.5         8.5         7.5       9.5    8.7            8.7
# 231          9.0         9.0         8.0       8.0   10.0            9.0
# 312          9.4         9.3         9.4       9.4    9.9            9.5
#
#             lon        lat
# 90          NaN        NaN
# 231  135.467370  34.751975
# ...

# %%
tokyo_hostel = []

for index, row in hostel_data.iterrows():
    if row["valueformoney"] == 10:
        tokyo_hostel.append(row)
        
tokyo_hostel = pd.DataFrame(tokyo_hostel)

tokyo_hostel
# Out:
#      Unnamed: 0                              hostel.name          City  \
# 12           13                     Akihabara Hotel 3000         Tokyo
# 29           30         Beagle Tokyo Hostel & Apartments         Tokyo
# 47           48                   Capsule Inn Kinshichou         Tokyo
# 54           55                              Chaganjutei         Kyoto
# 57           58                                  Colours         Kyoto
# 59           60                   Common de Hostel & Bar  Fukuoka-City
# 70           71                              Friends Kyo         Kyoto
# 76           77                         Goen Lounge＆Stay         Osaka
# 78           79                  Gojo Guesthouse - Annex         Kyoto
# 86           87                       Guest House Denchi         Tokyo
# 88           89                        Guest House Hachi         Kyoto
# 95           96                        Guest House ODORI         Osaka
# ...

# %%
tokyo_security_hostel = []

for index, row in hostel_data.iterrows():
    if row["security"] == 10:
        tokyo_security_hostel.append(row)
        
tokyo_security_hostel = pd.DataFrame(tokyo_security_hostel)

tokyo_security_hostel
# Out:
#      Unnamed: 0                                   hostel.name          City  \
# 2             3                         &And Hostel Akihabara         Tokyo
# 12           13                          Akihabara Hotel 3000         Tokyo
# 21           22                            Asakusahotel Wasou         Tokyo
# 23           24                     B&S Eco Cube Shinsaibashi         Osaka
# 32           33                            Bigtree Guesthouse         Osaka
# 46           47        Capsule Hotel Asahi Plaza Shinsaibashi         Osaka
# 47           48                        Capsule Inn Kinshichou         Tokyo
# 57           58                                       Colours         Kyoto
# 59           60                        Common de Hostel & Bar  Fukuoka-City
# 70           71                                   Friends Kyo         Kyoto
# 78           79                       Gojo Guesthouse - Annex         Kyoto
# ...

# %%
worst_atmosphere_hostel = []

for index, row in hostel_data.iterrows():
    if row["atmosphere"] <= 2:
        worst_atmosphere_hostel.append(row)
        
worst_atmosphere_hostel = pd.DataFrame(worst_atmosphere_hostel)

worst_atmosphere_hostel
# Out:
#      Unnamed: 0                     hostel.name   City  price.from  \
# 67           68                    Ezstay Osaka  Osaka        2000
# 140         141                Hostel Ginkakuji  Kyoto        1300
# 226         227                         Lucky's  Osaka        2500
# 290         291  Shibamata FU-TEN Bed and Local  Tokyo        3000
#
#                     Distance  summary.score rating.band  atmosphere  \
# 67    4.6km from city centre            3.1      Rating         2.0
# 140   2.7km from city centre            4.9      Rating         2.0
# 226   3.2km from city centre            7.7   Very Good         2.0
# 290  18.5km from city centre            4.9      Rating         2.0
#
#      cleanliness  facilities  location.y  security  staff  valueformoney  \
# 67           2.0         2.0         4.0       6.0    2.0            4.0
# 140         10.0         6.0         6.0       2.0    2.0            6.0
# ...
